# %%
1
# Out:
# 1

# %%
num1=10
num2=30
add= num1+num2
print("the num1:",num1)
print("the num2:",num2)
print("the add:",add)
# Out:
# the num1: 10
# the num2: 30
# the add: 40

# %%
bmi =int(input("Enter the bmi:"))

if bmi<18.5:
    print("under weight")
elif bmi<25:
    print("normal")
elif bmi<30:
    print("overweight")
else:
    print("very overweight")
# Out:
# Enter the bmi: 34
# very overweight
