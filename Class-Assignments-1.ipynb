# %%
fields=['Machine Learning', 'Neural Network', 'Vision', 'Robotics', 'Speech Processing',  'Natural Language processing']
print("Sub-Fields in AI are:")
for f in fields:
    print(f)

# %%
def subfield():
    fields=['Machine Learning', 'Neural Network', 'Vision', 'Robotics', 'Speech Processing',  'Natural Language processing']
    print("Sub-Fields in AI are:")
    for f in fields:
        print(f)
subfield()

# %%
class subfieldsAI():
    def subfield():
        fields=['Machine Learning', 'Neural Network', 'Vision', 'Robotics', 'Speech Processing',  'Natural Language processing']
        print("Sub-Fields in AI are:")
        for f in fields:
             print(f)
subfieldsAI.subfield()
# Out:
# Sub-Fields in AI are:
# Machine Learning
# Neural Network
# Vision
# Robotics
# Speech Processing
# Natural Language processing

# %%
number=int(input("Enter the number"))
if number % 2 == 0:
    print(number,"is Even number")
else:
    print(number, "is odd number")

# %%
class OddEven():
    def OddEven():
       number=int(input("Enter the number"))
       if number % 2 == 0:
        print(number,"is Even number")
       else:
         print(number, "is odd number")
OddEven()
OddEven.OddEven()
# Out:
# Enter the number 52452
# 52452 is Even number

# %%
class ElegibilityforMarriage():
    def eligible():
        gender = input("Your Gender: ")
        age = int(input("Your Age: "))
        if gender.lower() == "male":
            if age >= 21:
                print("eligible")
            else:
                print("not eligible")
        elif gender.lower() == "female":
            if age >= 18:        
                print("eligible")
            else:                
                print("not eligible")
    
ElegibilityforMarriage.eligible()
# Out:
# Your Gender:  male
# Your Age:  20
# not eligible

# %%
def percentage():
    sub1 = int(input("Subject1= "))
    sub2 = int(input("Subject2= "))
    sub3 = int(input("Subject3= "))
    sub4 = int(input("Subject4= "))
    sub5 = int(input("Subject5= "))
    total = sub1 + sub2 + sub3 + sub4 + sub5
    print("Total:", total)
    print("Percentage:", (total / 500) * 100)

percentage()

# %%
class FindPercent():
    def percentage():
        sub1 = int(input("Subject1= "))
        sub2 = int(input("Subject2= "))
        sub3 = int(input("Subject3= "))
        sub4 = int(input("Subject4= "))
        sub5 = int(input("Subject5= "))
        total = sub1 + sub2 + sub3 + sub4 + sub5
        print("Total:", total)
        print("Percentage:", (total / 500) * 100)

FindPercent.percentage()
# Out:
# Subject1=  98
# Subject2=  87
# Subject3=  95
# Subject4=  95
# Subject5=  93
# Total: 468
# Percentage: 93.60000000000001

# %%
class triangle():
    def triangle():
        height = int(input("Height: "))
        breadth = int(input("Breadth: "))
        print("Area:", (height * breadth) / 2)
        h1 = int(input("Height1: "))
        h2 = int(input("Height2: "))
        b = int(input("Breadth: "))
        print("Perimeter:", h1 + h2 + b)
triangle()
triangle.triangle()
# Out:
# Height:  32
# Breadth:  34
# Area: 544.0
# Height1:  2
# Height2:  4
# Breadth:  4
# Perimeter: 10
