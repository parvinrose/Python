# %%
1

# %%
for r in range(1,20):
    print(r)

# %%
for r in range(10,20):
    print(r, end=" ")

# %%
List2 =[10, 20, 14, 55, 43, 87, 76]
print(List2)
print("Number of item in the List2:")
print(len(List2))

# %%
text = Artifical Intelligence
for char in text:
    print(char)

# %%
text = "Artifical Intelligence"
for char in text:
    print(char)

# %%
print("-Your Name - parvin A")

# %%
print("-Your Name- parvin A")
print("-Your Age- 23")
print("-Your profession - full stack developer")

# %%
m = [1, 'welcome', 2, 'hope']
print(m)

# %%
numbers(20, 10, 16, 19, 25, 1, 276, 188)
print(numbers)
for n in numbers:
    if n%2 == 0:
        print(n, "is even")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 numbers(20, 10, 16, 19, 25, 1, 276, 188)
#       2 print(numbers)
#       3 for n in numbers:
#
# NameError: name 'numbers' is not defined

# %%
numbers=(20, 10, 16, 19, 25, 1, 276, 188)
print(numbers)
for n in numbers:
    if n%2 == 0:
        print(n, "is even")
# Out:
# (20, 10, 16, 19, 25, 1, 276, 188)
# 20 is even
# 10 is even
# 16 is even
# 276 is even
# 188 is even

# %%
numbers=(20, 10, 16, 19, 25, 1, 276, 188)
print(numbers)
for n in numbers:
    if n%2 != 0:
        print(n, "is odd")
# Out:
# (20, 10, 16, 19, 25, 1, 276, 188)
# 19 is odd
# 25 is odd
# 1 is odd
