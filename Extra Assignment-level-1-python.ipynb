# %% [raw]
# print("HOPE AI")

# %%
print("HOPE AI")

# %%
institute =input("Enter your institute name?:")
# Out:
# Enter your institute name?: HOPE AI

# %%
name =input("Enter your name:")
age =int(input("Enter your age:"))
schoolname =input("Enter your  school name:")
degree =input("Enter your degree:")
# Out:
# Enter your name: parvin A
# Enter your age: 23
# Enter your  school name: texcity arts and science college
# Enter your degree: bsc  computer science

# %%
a=43
b=34
add=a+b
print("a=",a)
print("b=",b)
print("add=",add)
# Out:
# a= 43
# b= 34
# add= 77

# %%
a=43
b=34
sub=a-b
print("a=",a)
print("b=",b)
print("sub=",sub)
# Out:
# a= 43
# b= 34
# sub= 9

# %%
a=63
b=97
mul=a*b
print("a=",a)
print("b=",b)
print("mul=",mul)
# Out:
# a= 63
# b= 97
# mul= 6111

# %%
a=76
b=31
floatdiv=a/b
print("a=",a)
print("b=",b)
print("floatdiv=",floatdiv)
# Out:
# a= 76
# b= 31
# floatdiv= 2.4516129032258065

# %%
a=76
b=31
floordiv=a//b
print("a=",a)
print("b=",b)
print("floordiv=",floordiv)
# Out:
# a= 76
# b= 31
# floordiv= 2

# %%
a=76
b=31
modulo=a%b
print("a=",a)
print("b=",b)
print("modulo=",modulo)
# Out:
# a= 76
# b= 31
# modulo= 14

# %%
a=4
b=4
power=a**b
print("a=",a)
print("b=",b)
print("power=",power)
# Out:
# a= 4
# b= 4
# power= 256
